# %%
#Crime Type: Terrorist Attacks

import pandas as pd
df = pd.read_csv("tasfia_haque_data.csv")
print(df.sort_values('Terrorism deaths', ascending=False))
# Out:
#          Entity      Code  Year  Terrorist attacks  Terrorism deaths  \
# 10221     World  OWID_WRL  2014              16820             44576
# 10222     World  OWID_WRL  2015              14888             38876
# 10223     World  OWID_WRL  2016              13876             35109
# 481        Asia       NaN  2014              11876             28445
# 10224     World  OWID_WRL  2017              11275             26843
# ...         ...       ...   ...                ...               ...
# 4161   Honduras       HND  2018                  0                 0
# 4158   Honduras       HND  2015                  0                 0
# 4157   Honduras       HND  2014                  1                 0
# 4155   Honduras       HND  2012                  0                 0
# 10516  Zimbabwe       ZWE  2021                  0                 0
#
#        Attack method: Hijacking  \
# 10221                        48
# 10222                        40
# 10223                        43
# ...
