# %%
import pandas as pd
df = pd.read_csv('data/data.csv')

# %%
df['CMPLNT_NUM']
# Out:
# 0     286159230
# 1     284390764
# 2     282326671
# 3     281045110
# 4     282616059
# 5     283299802
# 6     285354060
# 7     283173106
# 8     285539608
# 9     281731995
# 10    284167496
# Name: CMPLNT_NUM, dtype: int64

# %%
df.head()
# Out:
#    CMPLNT_NUM  ADDR_PCT_CD    BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT  \
# 0   286159230           24  MANHATTAN   01/01/2016     15:00:00   01/01/2018
# 1   284390764           13  MANHATTAN   01/01/2016     12:00:00   03/26/2024
# 2   282326671           28  MANHATTAN   01/10/2016     12:00:00   01/10/2016
# 3   281045110           23  MANHATTAN   01/25/2016     00:01:00          NaN
# 4   282616059            5  MANHATTAN   05/11/2016     09:30:00   05/11/2016
#
#   CMPLNT_TO_TM CRM_ATPT_CPTD_CD HADEVELOPT           JURIS_DESC  ...  \
# 0     23:00:00        COMPLETED     (null)  N.Y. HOUSING POLICE  ...
# 1     12:00:00        COMPLETED     (null)     N.Y. POLICE DEPT  ...
# 2     12:00:00        COMPLETED     (null)     N.Y. POLICE DEPT  ...
# 3       (null)        COMPLETED     (null)  N.Y. HOUSING POLICE  ...
# 4     10:00:00        COMPLETED     (null)     N.Y. POLICE DEPT  ...
#
#    PARKS_NM PD_CD                         PD_DESC               PREM_TYP_DESC  \
# ...
