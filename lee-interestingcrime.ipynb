# %%
import pandas as pd
df = pd.read_csv('data/data.csv')
df = df[df.BORO_NM == 'MANHATTAN']
df.head()
# Out:
#    CMPLNT_NUM  ADDR_PCT_CD    BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT  \
# 16  279769488            1  MANHATTAN   01/01/2024     06:49:00   01/01/2024
# 21  279799762            1  MANHATTAN   01/01/2024     15:30:00   01/01/2024
# 26  279792819            1  MANHATTAN   01/01/2024     20:00:00   01/01/2024
# 34  279768924            5  MANHATTAN   01/01/2024     03:20:00   01/01/2024
# 38  279968161            6  MANHATTAN   01/01/2024     01:00:00   01/01/2024
#
#    CMPLNT_TO_TM CRM_ATPT_CPTD_CD HADEVELOPT  HOUSING_PSA  ...  \
# 16     06:50:00        COMPLETED     (null)          NaN  ...
# 21     15:45:00        COMPLETED     (null)          NaN  ...
# 26     20:20:00        COMPLETED     (null)          NaN  ...
# 34     03:50:00        COMPLETED     (null)          NaN  ...
# 38     01:05:00        COMPLETED     (null)          NaN  ...
#
#     TRANSIT_DISTRICT VIC_AGE_GROUP                  VIC_RACE VIC_SEX  \
# ...

# %%
specific_crime = df[df.OFNS_DESC == "FRAUDS"]
specific_crime.head()
# Out:
#      CMPLNT_NUM  ADDR_PCT_CD    BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM  \
# 303   282568558           18  MANHATTAN   01/01/2024     09:00:00
# 3776  279887267           30  MANHATTAN   01/03/2024     11:46:00
# 4786  282058330            5  MANHATTAN   01/04/2024     10:00:00
# 5106  287798791           19  MANHATTAN   01/04/2024     09:00:00
# 6286  281154434            1  MANHATTAN   01/05/2024     12:00:00
#
#      CMPLNT_TO_DT CMPLNT_TO_TM CRM_ATPT_CPTD_CD HADEVELOPT  HOUSING_PSA  ...  \
# 303    01/01/2024     10:00:00        COMPLETED     (null)          NaN  ...
# 3776   01/03/2024     11:48:00        COMPLETED     (null)          NaN  ...
# 4786   01/08/2024     09:00:00        COMPLETED     (null)          NaN  ...
# 5106   05/30/2024     14:20:00        COMPLETED     (null)          NaN  ...
# 6286   01/26/2024     10:00:00        COMPLETED     (null)          NaN  ...
#
#       TRANSIT_DISTRICT VIC_AGE_GROUP                  VIC_RACE VIC_SEX  \
# ...

# %%
specific_crime = specific_crime.sort_values("ADDR_PCT_CD")
specific_crime.head()
# Out:
#        CMPLNT_NUM  ADDR_PCT_CD    BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM  \
# 90733   283072085            1  MANHATTAN   03/02/2024     04:52:00
# 55192   281812400            1  MANHATTAN   02/07/2024     08:56:00
# 106903  283682856            1  MANHATTAN   03/13/2024     16:22:00
# 29223   280883647            1  MANHATTAN   01/21/2024     18:51:00
# 27872   280846764            1  MANHATTAN   01/20/2024     19:48:00
#
#        CMPLNT_TO_DT CMPLNT_TO_TM CRM_ATPT_CPTD_CD HADEVELOPT  HOUSING_PSA  \
# 90733    03/02/2024     04:52:00        COMPLETED     (null)          NaN
# 55192    02/07/2024     08:56:00        COMPLETED     (null)          NaN
# 106903   03/13/2024     16:48:00        COMPLETED     (null)          NaN
# 29223    01/21/2024     18:51:00        COMPLETED     (null)          NaN
# 27872    01/20/2024     19:48:00        COMPLETED     (null)          NaN
#
#         ...  TRANSIT_DISTRICT VIC_AGE_GROUP  VIC_RACE VIC_SEX X_COORD_CD  \
# ...
