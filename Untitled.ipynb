# %%
import pandas as pd
import sqlite3

con = sqlite3.connect("/Users/kailynconaway/Documents/GitHub/UMD-INST627-Fall2024/data/nba.sqlite")
games = pd.read_sql_query("SELECT * FROM game ORDER BY game_date DESC LIMIT 500", con)
active_players = pd.read_sql_query("SELECT full_name FROM player WHERE is_active=TRUE", con)

#Question reminders:
#1. (USING) Which teams have most consistently had the highest scores?
#2. (USING) Which team has had below average for the most consecutive seasons?
#3. (USING) Which team has consistently made it to the playoffs?
#4. Does a higher proportion of three-point field goals increase the likelihood of winning? 
#5. How does the frequency of turnovers in a game affect the likelihood of winning? Simply put, do more turnovers help or hinder? 
#6. (USING) Which teams have shown the greatest improvement over the past five years?
#7. (USING) Which teams have demonstrated the best defensive metrics (e.g., blocks and steals), and how has this impacted their winning consistency?

#Intro: Question 1 discusses the best teams of our all time data but does not take recent stats into consideration.
#Question 3 does similar by capturing all-time playoffs, these can be used as an introduction since they are simple to explain and visualize.

#Rising action: Question 2 shows the flip-side to remind stakeholders that money can be lost and it's important to consider every metric.
#I think we can hone in on this question even more by reviewing the last 5 to 10 years of data.

#Climax: Question 6 discusses which teams have done the best recently. We can answer Question 7 to see if there is a correlation.
#If there us a correlation we can use this information for best players and what team they are currently on.

#Falling action: 

#Conclusion: What teams have the best players compared to/as well as what teams are most likely to do well in playoffs?
# Out:
#     season_id team_id_home team_abbreviation_home        team_name_home  \
# 0       42022   1610612743                    DEN        Denver Nuggets
# 1       42022   1610612748                    MIA            Miami Heat
# 2       42022   1610612748                    MIA            Miami Heat
# 3       42022   1610612743                    DEN        Denver Nuggets
# 4       42022   1610612743                    DEN        Denver Nuggets
# ..        ...          ...                    ...                   ...
# 495     22022   1610612745                    HOU       Houston Rockets
# 496     22022   1610612747                    LAL    Los Angeles Lakers
# 497     22022   1610612740                    NOP  New Orleans Pelicans
# 498     22022   1610612753                    ORL         Orlando Magic
# 499     22022   1610612751                    BKN         Brooklyn Nets
#
#         game_id            game_date matchup_home wl_home  min  fgm_home  ...  \
# ...
