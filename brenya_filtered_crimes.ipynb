# %%
import pandas as pd 
df = pd.read_csv('data/data.csv')
df = df [df.PD_DESC == 'SEXUAL ABUSE 3,2']
df['RPT_DT'] = pd.to_datetime(df['RPT_DT'], errors='coerce')
df_sorted = df.sort_values(by='RPT_DT')
df
# Out:
#        CMPLNT_NUM  ADDR_PCT_CD        BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM  \
# 9       279802438          120  STATEN ISLAND   01/01/2024     08:57:00
# 48      283189135           72       BROOKLYN   01/01/2024     00:01:00
# 62      279833467            5      MANHATTAN   01/01/2024     01:30:00
# 116     279767608           14      MANHATTAN   01/01/2024     03:25:00
# 119     287559757            5      MANHATTAN   01/01/2024     00:00:00
# ...           ...          ...            ...          ...          ...
# 133782  284589552           50          BRONX   03/31/2024     19:00:00
# 133848  284579890           41          BRONX   03/31/2024     00:00:00
# 133948  285811052           43          BRONX   03/31/2024     00:00:00
# 134065  284995772           45          BRONX   03/31/2024     05:00:00
# 134128  284565980          111         QUEENS   03/31/2024     02:00:00
#
#        CMPLNT_TO_DT CMPLNT_TO_TM CRM_ATPT_CPTD_CD HADEVELOPT  HOUSING_PSA  \
# ...
