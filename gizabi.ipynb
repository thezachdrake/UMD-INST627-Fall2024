# %%
import pandas as pd 
df = pd.read_csv('data/data.csv')
df
# Out:
#        CMPLNT_NUM  ADDR_PCT_CD        BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM  \
# 0       279815523           72       BROOKLYN   01/01/2024     07:00:00
# 1       279780204          122  STATEN ISLAND   01/01/2024     02:20:00
# 2       279780194          120  STATEN ISLAND   01/01/2024     01:40:00
# 3       279780059           66       BROOKLYN   01/01/2024     00:02:00
# 4       280014366          120  STATEN ISLAND   01/01/2024     22:50:00
# ...           ...          ...            ...          ...          ...
# 134634  284588555          111         QUEENS   03/31/2024     18:40:00
# 134635  284588545          101         QUEENS   03/31/2024     22:35:00
# 134636  284640813          101         QUEENS   03/31/2024     20:20:00
# 134637  284721086          105         QUEENS   03/31/2024     00:30:00
# 134638  284584388          103         QUEENS   03/31/2024     17:50:00
#
#        CMPLNT_TO_DT CMPLNT_TO_TM CRM_ATPT_CPTD_CD HADEVELOPT  HOUSING_PSA  \
# ...

# %%
import pandas as pd 
df = pd.read_csv('data/data.csv')
df = df['PD_DESC'] 
df
# Out:
# 0           MISCHIEF, CRIMINAL 3 & 2, OF M
# 1           MISCHIEF, CRIMINAL 3 & 2, OF M
# 2           MISCHIEF, CRIMINAL 4, OF MOTOR
# 3                    LARCENY,GRAND OF AUTO
# 4         CRIMINAL MISCHIEF,UNCLASSIFIED 4
#                         ...
# 134634                           ASSAULT 3
# 134635      THEFT OF SERVICES, UNCLASSIFIE
# 134636                           ASSAULT 3
# 134637               HARASSMENT,SUBD 3,4,5
# 134638                           ASSAULT 3
# Name: PD_DESC, Length: 134639, dtype: object

# %%
import pandas as pd 
df = pd.read_csv('data/data.csv')
df = df['PD_DESC'].unique()
df
# Out:
# array(['MISCHIEF, CRIMINAL 3 & 2, OF M', 'MISCHIEF, CRIMINAL 4, OF MOTOR',
#        'LARCENY,GRAND OF AUTO', 'CRIMINAL MISCHIEF,UNCLASSIFIED 4',
#        'HARASSMENT,SUBD 1,CIVILIAN', 'FRAUD,UNCLASSIFIED-MISDEMEANOR',
#        'SEXUAL ABUSE 3,2', 'LARCENY,PETIT FROM OPEN AREAS,',
#        'LARCENY,PETIT FROM STORE-SHOPL', 'BURGLARY,COMMERCIAL,DAY',
#        'TRAFFIC,UNCLASSIFIED MISDEMEAN', 'ASSAULT 2,1,UNCLASSIFIED',
#        'LARCENY,PETIT FROM AUTO', 'CONTROLLED SUBSTANCE,POSSESS.',
#        'LARCENY,GRAND BY THEFT OF CREDIT CARD',
#        'LARCENY,GRAND BY FALSE PROMISE-NOT IN PERSON CONTACT',
#        'VIOLATION OF ORDER OF PROTECTI', '(null)', 'STRANGULATION 1ST',
#        'ROBBERY,PERSONAL ELECTRONIC DEVICE',
#        'INTOXICATED DRIVING,ALCOHOL', 'BRIBERY,PUBLIC ADMINISTRATION',
#        'AGGRAVATED HARASSMENT 2', 'MISCHIEF,CRIMINAL,    UNCL 2ND',
#        'WEAPONS, POSSESSION, ETC', 'FORGERY,ETC.,UNCLASSIFIED-FELO',
#        'LARCENY,GRAND FROM RESIDENCE, UNATTENDED',
# ...

# %%
import pandas as pd 
df = pd.read_csv('data/data.csv')
df = df [df.OFNS_DESC == 'GRAND LARCENY']
df
# Out:
#        CMPLNT_NUM  ADDR_PCT_CD    BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM  \
#