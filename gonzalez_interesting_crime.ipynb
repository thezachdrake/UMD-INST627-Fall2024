# %%
import pandas as pd
# Perry Gonzalez, issue 1
# filtering by grand larceny crime
df = pd.read_csv("data/data.csv")
# i set pandas to show all column names because it wasn't showing the crime column name or data
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
df = df[df.OFNS_DESC == "GRAND LARCENY"]
# i set this just to show the first few rows for performance reasons
df.head()
# Out:
#    CMPLNT_NUM  ADDR_PCT_CD    BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT  \
# 26  279792819            1  MANHATTAN   01/01/2024     20:00:00   01/01/2024
# 30  280023723           62   BROOKLYN   01/01/2024     21:00:00   01/03/2024
# 52  283413921            6  MANHATTAN   01/01/2024     10:00:00   02/20/2024
# 53  279932191           84   BROOKLYN   01/01/2024     20:00:00   01/01/2024
# 69  279837268           13  MANHATTAN   01/01/2024     19:32:00   01/02/2024
#
#    CMPLNT_TO_TM CRM_ATPT_CPTD_CD HADEVELOPT  HOUSING_PSA  JURISDICTION_CODE  \
# 26     20:20:00        COMPLETED     (null)          NaN                  0
# 30     21:00:00        COMPLETED     (null)          NaN                  0
# 52     10:00:00        COMPLETED     (null)          NaN                  0
# 53     20:30:00        COMPLETED     (null)          NaN                  0
# 69     19:52:00        COMPLETED     (null)          NaN                  0
#
# ...
