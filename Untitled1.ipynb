# %%
import pandas as pd
import sqlite3

con = sqlite3.connect("data/nba.sqlite")
covid_wl_home = pd.read_sql_query("SELECT * FROM game WHERE season_id IN (22022, 22021, 22020, 22019) ORDER BY season_id DESC", con)
covid_wl_home
# Out:
#      season_id team_id_home team_abbreviation_home         team_name_home  \
# 0        22022   1610612738                    BOS         Boston Celtics
# 1        22022   1610612744                    GSW  Golden State Warriors
# 2        22022   1610612765                    DET        Detroit Pistons
# 3        22022   1610612762                    UTA              Utah Jazz
# 4        22022   1610612751                    BKN          Brooklyn Nets
# ...        ...          ...                    ...                    ...
# 4594     22019   1610612751                    BKN          Brooklyn Nets
# 4595     22019   1610612746                    LAC            LA Clippers
# 4596     22019   1610612754                    IND         Indiana Pacers
# 4597     22019   1610612745                    HOU        Houston Rockets
# 4598     22019   1610612761                    TOR        Toronto Raptors
#
#          game_id            game_date matchup_home wl_home  min  fgm_home  \
# ...
