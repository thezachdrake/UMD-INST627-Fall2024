# %%
import pandas as pd

crimes = pd.read_csv('data/data.csv', index_col=0)

misd_crimes = crimes[crimes['LAW_CAT_CD']=="MISDEMEANOR"]

sort_age = misd_crimes.sort_values(by=['VIC_AGE_GROUP'], ascending=True)

print(sort_age)
# Out:
#             ADDR_PCT_CD        BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT  \
# CMPLNT_NUM
# 283167221            63       BROOKLYN   03/01/2024     09:10:00   03/01/2024
# 281956306             1      MANHATTAN   02/09/2024     13:09:00   02/09/2024
# 283012318           123  STATEN ISLAND   03/01/2024     00:20:00   03/01/2024
# 281021181            23      MANHATTAN   01/24/2024     06:20:00   01/24/2024
# 282108824           114         QUEENS   02/10/2024     15:30:00   02/10/2024
# ...                 ...            ...          ...          ...          ...
# 282657946            69       BROOKLYN   02/22/2024     11:40:00   02/22/2024
# 282608288            75       BROOKLYN   02/22/2024     02:55:00   02/22/2024
# 282643740           115         QUEENS   02/22/2024     14:10:00          NaN
# 282598029            46          BRONX   02/22/2024     00:05:00   02/22/2024
# 282947627            14      MANHATTAN   02/28/2024     14:40:00   02/28/2024
#
# ...
