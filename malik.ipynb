# %%
import pandas as pd
df = pd.read_csv("data/data.csv")
df = df[df.BORO_NM == "MANHATTAN"]
df
# Out:
#     CMPLNT_NUM  ADDR_PCT_CD    BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT  \
# 0    286159230           24  MANHATTAN   01/01/2016     15:00:00   01/01/2018
# 1    284390764           13  MANHATTAN   01/01/2016     12:00:00   03/26/2024
# 2    282326671           28  MANHATTAN   01/10/2016     12:00:00   01/10/2016
# 3    281045110           23  MANHATTAN   01/25/2016     00:01:00          NaN
# 4    282616059            5  MANHATTAN   05/11/2016     09:30:00   05/11/2016
# 5    283299802           24  MANHATTAN   06/01/2016     15:33:00   06/01/2016
# 6    285354060           18  MANHATTAN   06/01/2016     17:00:00   03/01/2024
# 7    283173106           28  MANHATTAN   06/21/2016     01:56:00   06/21/2016
# 8    285539608           30  MANHATTAN   07/24/2016     00:01:00   07/23/2017
# 9    281731995           14  MANHATTAN   10/01/2016     00:00:00   09/10/2019
# 10   284167496           34  MANHATTAN   12/01/2016     00:01:00   12/31/2016
#
# ...

# %%
#filtering the data for grand larceny crimes and sorting by location type
import pandas as pd
df = pd.read_csv("data/data.csv")
grand_larceny_crimes = df[df['OFNS_DESC'] == 'GRAND LARCENY']
grand_larceny_crimes = grand_larceny_crimes.sort_values("PREM_TYP_DESC")
grand_larceny_crimes
# Out:
#        CMPLNT_NUM  ADDR_PCT_CD    BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM  \
# 134631  284573381          102     QUEENS   03/31/2024     03:00:00
# 56342   281846743           34  MANHATTAN   02/07/2024     07:25:00
# 61918   282162405            9  MANHATTAN   02/11/2024     02:00:00
# 22337   280604660           84   BROOKLYN   01/16/2024     15:06:00
# 35074   282203060           13  MANHATTAN   01/25/2024     08:00:00
# ...           ...          ...        ...          ...          ...
# 33067   280965247          114     QUEENS   01/23/2024     09:30:00
# 109085  283877234           48      BRONX   03/14/2024     15:10:00
# 31371   280929080           41      BRONX   01/22/2024     18:05:00
# 66192   282385834           52      BRONX   02/14/2024     12:00:00
# 65733   282228602           78   BROOKLYN   02/14/2024     13:20:00
#
#        CMPLNT_TO_DT CMPLNT_TO_TM CRM_ATPT_CPTD_CD HADEVELOPT  HOUSING_PSA  \
# 134631   03/31/2024     10:00:00        COMPLETED     (null)          NaN
# ...

# %%
import pandas as pd
df = pd.read_csv("data/data.csv")
grand_larceny_crimes = df[df['OFNS_DESC'] == 'GRAND LARCENY']
grand_larceny_crimes = grand_larceny_crimes.sort_values("PREM_TYP_DESC")
grand_larceny_crimes
# Out:
#        CMPLNT_NUM  ADDR_PCT_CD    BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM  \
# 134631  284573381          102     QUEENS   03/31/2024     03:00:00
# 56342   281846743           34  MANHATTAN   02/07/2024     07:25:00
# 61918   282162405            9  MANHATTAN   02/11/2024     02:00:00
# 22337   280604660           84   BROOKLYN   01/16/2024     15:06:00
# 35074   282203060           13  MANHATTAN   01/25/2024     08:00:00
# ...           ...          ...        ...          ...          ...
# 33067   280965247          114     QUEENS   01/23/2024     09:30:00
# 109085  283877234           48      BRONX   03/14/2024     15:10:00
# 31371   280929080           41      BRONX   01/22/2024     18:05:00
# 66192   282385834           52      BRONX   02/14/2024     12:00:00
# 65733   282228602           78   BROOKLYN   02/14/2024     13:20:00
#
#        CMPLNT_TO_DT CMPLNT_TO_TM CRM_ATPT_CPTD_CD HADEVELOPT  HOUSING_PSA  \
# 134631   03/31/2024     10:00:00        COMPLETED     (null)          NaN
# ...
