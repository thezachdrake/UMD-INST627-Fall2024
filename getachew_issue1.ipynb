# %%
import pandas as pd
df = pd.read_csv("data/data.csv") 

#listing all the columns of the dataset to see which is the crime type column
print(list(df.columns))
# Out:
# ['CMPLNT_NUM', 'ADDR_PCT_CD', 'BORO_NM', 'CMPLNT_FR_DT', 'CMPLNT_FR_TM', 'CMPLNT_TO_DT', 'CMPLNT_TO_TM', 'CRM_ATPT_CPTD_CD', 'HADEVELOPT', 'HOUSING_PSA', 'JURISDICTION_CODE', 'JURIS_DESC', 'KY_CD', 'LAW_CAT_CD', 'LOC_OF_OCCUR_DESC', 'OFNS_DESC', 'PARKS_NM', 'PATROL_BORO', 'PD_CD', 'PD_DESC', 'PREM_TYP_DESC', 'RPT_DT', 'STATION_NAME', 'SUSP_AGE_GROUP', 'SUSP_RACE', 'SUSP_SEX', 'TRANSIT_DISTRICT', 'VIC_AGE_GROUP', 'VIC_RACE', 'VIC_SEX', 'X_COORD_CD', 'Y_COORD_CD', 'Latitude', 'Longitude', 'Lat_Lon', 'New Georeferenced Column']

# %%
#pick OFNS_DESC type and print all the distinct values for this column
unique_offenses = df['OFNS_DESC'].unique()
print(unique_offenses)
# Out:
# ['CRIMINAL MISCHIEF & RELATED OF' 'GRAND LARCENY OF MOTOR VEHICLE'
#  'HARRASSMENT 2' 'FRAUDS' 'SEX CRIMES' 'PETIT LARCENY' 'BURGLARY'
#  'VEHICLE AND TRAFFIC LAWS' 'FELONY ASSAULT' 'DANGEROUS DRUGS'
#  'GRAND LARCENY' 'OFFENSES AGAINST PUBLIC ADMINI'
#  'MURDER & NON-NEGL. MANSLAUGHTER' 'ROBBERY'
#  'INTOXICATED & IMPAIRED DRIVING' 'MISCELLANEOUS PENAL LAW'
#  'OFF. AGNST PUB ORD SENSBLTY &' 'DANGEROUS WEAPONS' 'FORGERY' 'RAPE'
#  'NYS LAWS-UNCLASSIFIED FELONY' 'OTHER STATE LAWS (NON PENAL LA'
#  'CRIMINAL TRESPASS' 'ASSAULT 3 & RELATED OFFENSES' 'ADMINISTRATIVE CODE'
#  'UNAUTHORIZED USE OF A VEHICLE' 'ARSON' 'OFFENSES INVOLVING FRAUD'
#  'OFFENSES AGAINST THE PERSON' 'THEFT-FRAUD'
#  'AGRICULTURE & MRKTS LAW-UNCLASSIFIED' 'OTHER OFFENSES RELATED TO THEF'
#  'POSSESSION OF STOLEN PROPERTY' 'CANNABIS RELATED OFFENSES' 'GAMBLING'
#  'KIDNAPPING & RELATED OFFENSES' "BURGLAR'S TOOLS"
#  'ALCOHOLIC BEVERAGE CONTROL LAW' 'PETIT LARCENY OF MOTOR VEHICLE'
# ...

# %%
#filter by kindnapping related crimes and sorting by the PD_DESC to see what the internal classification is fort each of the kinappings
#increased the number of visible rows to see the victim's age
pd.set_option('display.max_columns', 100)
df2 = df[df.OFNS_DESC == 'KIDNAPPING & RELATED OFFENSES']
df2.sort_values(by='PD_DESC',ascending=False)
df2
# Out:
#        CMPLNT_NUM  ADDR_PCT_CD    BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM  \
# 684     280068301           43      BRONX   01/01/2024     00:00:00
# 5152    280043932           69   BROOKLYN   01/04/2024     14:00:00
# 11135   280170008          106     QUEENS   01/08/2024     20:00:00
# 21153   280558866           42      BRONX   01/15/2024     20:20:00
# 22359   280580018           50      BRONX   01/16/2024     09:20:00
# 22398   280604615           42      BRONX   01/16/2024     15:18:00
# 47912   281580026           83   BROOKLYN   02/02/2024     23:20:00
# 50774   281650559           62   BROOKLYN   02/04/2024     14:40:00
# 50889   281637150          108     QUEENS   02/04/2024     07:00:00
# 57343   281899095           75   BROOKLYN   02/08/2024     14:00:00
# 61944   282083333           75   BROOKLYN   02/11/2024     18:26:00
# 70374   282454086           88   BROOKLYN   02/17/2024     20:00:00
# 70623   282403317          114     QUEENS   02/17/2024     17:30:00
# ...
