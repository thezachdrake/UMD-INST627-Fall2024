# %%
import pandas as pd

df = pd.read_csv('data/data.csv')
df_m = df[df['BORO_NM'] == 'MANHATTAN']
df_m.head()
# Out:
#    CMPLNT_NUM  ADDR_PCT_CD    BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT  \
# 16  279769488            1  MANHATTAN   01/01/2024     06:49:00   01/01/2024
# 21  279799762            1  MANHATTAN   01/01/2024     15:30:00   01/01/2024
# 26  279792819            1  MANHATTAN   01/01/2024     20:00:00   01/01/2024
# 34  279768924            5  MANHATTAN   01/01/2024     03:20:00   01/01/2024
# 38  279968161            6  MANHATTAN   01/01/2024     01:00:00   01/01/2024
#
#    CMPLNT_TO_TM CRM_ATPT_CPTD_CD HADEVELOPT  HOUSING_PSA  ...  \
# 16     06:50:00        COMPLETED     (null)          NaN  ...
# 21     15:45:00        COMPLETED     (null)          NaN  ...
# 26     20:20:00        COMPLETED     (null)          NaN  ...
# 34     03:50:00        COMPLETED     (null)          NaN  ...
# 38     01:05:00        COMPLETED     (null)          NaN  ...
#
#     TRANSIT_DISTRICT VIC_AGE_GROUP                  VIC_RACE VIC_SEX  \
# ...
