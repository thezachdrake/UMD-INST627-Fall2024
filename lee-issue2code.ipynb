# %%
import pandas as pd
df_arrests = pd.read_csv('data/arrests.csv')
df_arrests.head()
df_arrests.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128778 entries, 0 to 128777
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   ARREST_KEY                128778 non-null  int64
#  1   ARREST_DATE               128778 non-null  object
#  2   PD_CD                     128774 non-null  float64
#  3   PD_DESC                   128778 non-null  object
#  4   KY_CD                     128763 non-null  float64
#  5   OFNS_DESC                 128778 non-null  object
#  6   LAW_CODE                  128778 non-null  object
#  7   LAW_CAT_CD                128008 non-null  object
#  8   ARREST_BORO               128778 non-null  object
#  9   ARREST_PRECINCT           128778 non-null  int64
#  10  JURISDICTION_CODE         128778 non-null  int64
#  11  AGE_GROUP                 128778 non-null  object
#  12  PERP_SEX                  128778 non-null  object
# ...

# %%
df_crimes = pd.read_csv('data/crimes.csv')
df_crimes.info()
df_crimes.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125000 entries, 0 to 124999
# Data columns (total 37 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Unnamed: 0                125000 non-null  int64
#  1   CMPLNT_NUM                125000 non-null  object
#  2   ADDR_PCT_CD               125000 non-null  int64
#  3   BORO_NM                   125000 non-null  object
#  4   CMPLNT_FR_DT              125000 non-null  object
#  5   CMPLNT_FR_TM              125000 non-null  object
#  6   CMPLNT_TO_DT              118306 non-null  object
#  7   CMPLNT_TO_TM              125000 non-null  object
#  8   CRM_ATPT_CPTD_CD          125000 non-null  object
#  9   HADEVELOPT                125000 non-null  object
#  10  HOUSING_PSA               7762 non-null    float64
#  11  JURISDICTION_CODE         125000 non-null  int64
#  12  JURIS_DESC                125000 non-null  object
# ...

# %%
arrests = pd.merge(df_arrests,df_crimes, on =[ 'Latitude', 'Longitude'])
arrests.head()
# Out:
#    ARREST_KEY ARREST_DATE  PD_CD_x PD_DESC_x  KY_CD_x OFNS_DESC_x    LAW_CODE  \
# 0   279884335  01/03/2024    153.0    RAPE 3    104.0        RAPE  PL 1302503
# 1   279884335  01/03/2024    153.0    RAPE 3    104.0        RAPE  PL 1302503
# 2   279884335  01/03/2024    153.0    RAPE 3    104.0        RAPE  PL 1302503
# 3   279884335  01/03/2024    153.0    RAPE 3    104.0        RAPE  PL 1302503
# 4   279884335  01/03/2024    153.0    RAPE 3    104.0        RAPE  PL 1302503
#
#   LAW_CAT_CD_x ARREST_BORO  ARREST_PRECINCT  ...  SUSP_RACE SUSP_SEX  \
# 0            F           K               77  ...      BLACK        M
# 1            F           K               77  ...    UNKNOWN        F
# 2            F           K               77  ...      BLACK        U
# 3            F           K               77  ...      BLACK        M
# 4            F           K               77  ...      BLACK        M
#
#   TRANSIT_DISTRICT VIC_AGE_GROUP  VIC_RACE  VIC_SEX  X_COORD_CD_y  \
# ...

# %%
arrests.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3008251 entries, 0 to 3008250
# Data columns (total 54 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   ARREST_KEY                  int64
#  1   ARREST_DATE                 object
#  2   PD_CD_x                     float64
#  3   PD_DESC_x                   object
#  4   KY_CD_x                     float64
#  5   OFNS_DESC_x                 object
#  6   LAW_CODE                    object
#  7   LAW_CAT_CD_x                object
#  8   ARREST_BORO                 object
#  9   ARREST_PRECINCT             int64
#  10  JURISDICTION_CODE_x         int64
#  11  AGE_GROUP                   object
#  12  PERP_SEX                    object
#  13  PERP_RACE                   object
#  14  X_COORD_CD_x                int64
#  15  Y_COORD_CD_x                int64
#  16  Latitude                    float64
#  17  Longitude                   float64
#  18  New Georeferenced Column_x  object
# ...
