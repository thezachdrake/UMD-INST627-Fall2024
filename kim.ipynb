# %%
import pandas as pd
df = pd.read_csv('data/data.csv')
df = df[df.BORO_NM=="MANHATTAN"]
df
# Out:
#        CMPLNT_NUM  ADDR_PCT_CD    BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM  \
# 16      279769488            1  MANHATTAN   01/01/2024     06:49:00
# 21      279799762            1  MANHATTAN   01/01/2024     15:30:00
# 26      279792819            1  MANHATTAN   01/01/2024     20:00:00
# 34      279768924            5  MANHATTAN   01/01/2024     03:20:00
# 38      279968161            6  MANHATTAN   01/01/2024     01:00:00
# ...           ...          ...        ...          ...          ...
# 134355  284575674           25  MANHATTAN   03/31/2024     10:12:00
# 134358  284578316           25  MANHATTAN   03/31/2024     10:12:00
# 134366  284655664           25  MANHATTAN   03/31/2024     08:25:00
# 134375  284718006           34  MANHATTAN   03/31/2024     20:00:00
# 134428  284852416           34  MANHATTAN   03/31/2024     07:00:00
#
#        CMPLNT_TO_DT CMPLNT_TO_TM CRM_ATPT_CPTD_CD HADEVELOPT  HOUSING_PSA  \
# 16       01/01/2024     06:50:00        COMPLETED     (null)          NaN
# 21       01/01/2024     15:45:00        COMPLETED     (null)          NaN
# 26       01/01/2024     20:20:00        COMPLETED     (null)          NaN
# 34       01/01/2024     03:50:00        COMPLETED     (null)          NaN
# 38       01/01/2024     01:05:00        COMPLETED     (null)          NaN
# ...             ...          ...              ...        ...          ...
# 134355   03/31/2024     11:40:00        COMPLETED     (null)          NaN
# 134358   03/31/2024     11:40:00        COMPLETED     (null)          NaN
# 134366   03/31/2024     08:35:00        COMPLETED     (null)          NaN
# 134375   03/31/2024     20:30:00        COMPLETED     (null)          NaN
# 134428   03/31/2024     17:07:00        COMPLETED     (null)          NaN
#
#         ...  TRANSIT_DISTRICT VIC_AGE_GROUP                  VIC_RACE VIC_SEX  \
# 16      ...               NaN       UNKNOWN                   UNKNOWN       D
# 21      ...               NaN         25-44  ASIAN / PACIFIC ISLANDER       M
# 26      ...               NaN         45-64                     WHITE       F
# 34      ...               NaN         45-64  ASIAN / PACIFIC ISLANDER       F
# 38      ...               NaN         18-24                     WHITE       F
# ...     ...               ...           ...                       ...     ...
# 134355  ...               NaN         18-24            WHITE HISPANIC       F
# 134358  ...               NaN         25-44            WHITE HISPANIC       F
# 134366  ...               NaN         45-64            WHITE HISPANIC       M
# 134375  ...               NaN         18-24                     WHITE       M
# 134428  ...               NaN       UNKNOWN                   UNKNOWN       D
#
#        X_COORD_CD Y_COORD_CD   Latitude  Longitude                  Lat_Lon  \
# 16       984004.0   202748.0  40.723175 -74.000886  (40.723175, -74.000886)
# 21       983665.0   203595.0  40.725499 -74.002108  (40.725499, -74.002108)
# 26       982972.0   201285.0  40.719160 -74.004609   (40.71916, -74.004609)
# 34       982707.0   199340.0  40.713820 -74.005564   (40.71382, -74.005564)
# 38       983697.0   206596.0  40.733736 -74.001995  (40.733736, -74.001995)
# ...           ...        ...        ...        ...                      ...
# 134355  1003638.0   226954.0  40.789593 -73.929984  (40.789593, -73.929984)
# 134358  1003638.0   226954.0  40.789593 -73.929984  (40.789593, -73.929984)
# 134366  1003638.0   226954.0  40.789593 -73.929984  (40.789593, -73.929984)
# 134375  1006101.0   253200.0  40.861624 -73.921003  (40.861624, -73.921003)
# 134428  1007617.0   256301.0  40.870131 -73.915509  (40.870131, -73.915509)
#
#             New Georeferenced Column
# 16      POINT (-74.000886 40.723175)
# 21      POINT (-74.002108 40.725499)
# 26       POINT (-74.004609 40.71916)
# 34       POINT (-74.005564 40.71382)
# 38      POINT (-74.001995 40.733736)
# ...                              ...
# 134355  POINT (-73.929984 40.789593)
# 134358  POINT (-73.929984 40.789593)
# 134366  POINT (-73.929984 40.789593)
# 134375  POINT (-73.921003 40.861624)
# 134428  POINT (-73.915509 40.870131)
#
# [31870 rows x 36 columns]

# %%
df = pd.read_csv('data/data.csv')
df = df[df.OFNS_DESC=="FORGERY"]
df.sort_values("PREM_TYP_DESC")
df
# Out:
#        CMPLNT_NUM  ADDR_PCT_CD    BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM  \
# 43      283046394            1  MANHATTAN   01/01/2024     12:00:00
# 140     279794668           18  MANHATTAN   01/01/2024     22:10:00
# 306     283795860           79   BROOKLYN   01/01/2024     00:00:00
# 378     279789943           81   BROOKLYN   01/01/2024     16:47:00
# 564     279786364           41      BRONX   01/01/2024     16:27:00
# ...           ...          ...        ...          ...          ...
# 133509  284584352           13  MANHATTAN   03/31/2024     17:43:00
# 133658  284588498           24  MANHATTAN   03/31/2024     21:55:00
# 133778  286387410           63   BROOKLYN   03/31/2024     12:00:00
# 134374  284562245          103     QUEENS   03/31/2024     02:20:00
# 134407  284565976          103     QUEENS   03/31/2024     04:50:00
#
#        CMPLNT_TO_DT CMPLNT_TO_TM CRM_ATPT_CPTD_CD HADEVELOPT  HOUSING_PSA  \
# 43       03/01/2024     14:49:00        COMPLETED     (null)          NaN
# 140      01/01/2024     22:15:00        COMPLETED     (null)          NaN
# 306      03/14/2024     18:30:00        COMPLETED     (null)          NaN
# 378      01/01/2024     17:06:00        COMPLETED     (null)          NaN
# 564      01/01/2024     16:35:00        COMPLETED     (null)          NaN
# ...             ...          ...              ...        ...          ...
# 133509   03/31/2024     18:04:00        COMPLETED     (null)          NaN
# 133658   03/31/2024     22:00:00        COMPLETED     (null)          NaN
# 133778   04/04/2024     12:00:00        COMPLETED     (null)          NaN
# 134374   03/31/2024     02:27:00        COMPLETED     (null)          NaN
# 134407   03/31/2024     05:19:00        COMPLETED     (null)          NaN
#
#         ...  TRANSIT_DISTRICT VIC_AGE_GROUP  VIC_RACE VIC_SEX X_COORD_CD  \
# 43      ...               NaN       UNKNOWN   UNKNOWN       D   982380.0
# 140     ...               NaN       UNKNOWN   UNKNOWN       E   988669.0
# 306     ...               NaN       UNKNOWN   UNKNOWN       D   998477.0
# 378     ...               NaN       UNKNOWN   UNKNOWN       E  1004919.0
# 564     ...               NaN       UNKNOWN   UNKNOWN       E  1014249.0
# ...     ...               ...           ...       ...     ...        ...
# 133509  ...               NaN       UNKNOWN   UNKNOWN       E   988276.0
# 133658  ...               NaN       UNKNOWN   UNKNOWN       D   995643.0
# 133778  ...               NaN           65+     WHITE       F  1011447.0
# 134374  ...               NaN       UNKNOWN   UNKNOWN       E  1037244.0
# 134407  ...               NaN       UNKNOWN   UNKNOWN       E  1044535.0
#
#        Y_COORD_CD   Latitude  Longitude  \
# 43       197844.0  40.709715 -74.006744
# 140      216684.0  40.761423 -73.984048
# 306      191688.0  40.692805 -73.948695
# 378      187068.0  40.680111 -73.925480
# 564      238403.0  40.820986 -73.891613
# ...           ...        ...        ...
# 133509   210451.0  40.744317 -73.985470
# 133658   230619.0  40.799665 -73.958848
# 133778   162943.0  40.613877 -73.902040
# 134374   195024.0  40.701814 -73.808874
# 134407   196357.0  40.705426 -73.782567
#
#                                          Lat_Lon  \
# 43                       (40.709715, -74.006744)
# 140        (40.7614228372042, -73.9840483917395)
# 306                      (40.692805, -73.948695)
# 378     (40.680111039841414, -73.92548046570226)
# 564       (40.82098580550746, -73.8916133211247)
# ...                                          ...
# 133509                    (40.744317, -73.98547)
# 133658                   (40.799665, -73.958848)
# 133778                    (40.613877, -73.90204)
# 134374   (40.70181387328086, -73.80887433026759)
# 134407   (40.70542596646755, -73.78256712062282)
#
#                              New Georeferenced Column
# 43                       POINT (-74.006744 40.709715)
# 140        POINT (-73.9840483917395 40.7614228372042)
# 306                      POINT (-73.948695 40.692805)
# 378     POINT (-73.92548046570226 40.680111039841414)
# 564       POINT (-73.8916133211247 40.82098580550746)
# ...                                               ...
# 133509                    POINT (-73.98547 40.744317)
# 133658                   POINT (-73.958848 40.799665)
# 133778                    POINT (-73.90204 40.613877)
# 134374   POINT (-73.80887433026759 40.70181387328086)
# 134407   POINT (-73.78256712062282 40.70542596646755)
#
# [1863 rows x 36 columns]
