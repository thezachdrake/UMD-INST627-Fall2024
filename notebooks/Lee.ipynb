# %% [markdown]
# Issue 3

# %%
import pandas as pd
import sqlite3

# %%
con = sqlite3.connect("data/nba.sqlite") 
games = pd.read_sql_query("SELECT * FROM game LIMIT 100", con)
active_players = pd.read_sql_query("SELECT full_name FROM player WHERE is_active=TRUE", con)

# %%
active_players
# Out:
#             full_name
# 0    Precious Achiuwa
# 1        Steven Adams
# 2         Bam Adebayo
# 3        Ochai Agbaji
# 4        Santi Aldama
# ..                ...
# 530    Thaddeus Young
# 531        Trae Young
# 532    Omer Yurtseven
# 533       Cody Zeller
# 534       Ivica Zubac
#
# [535 rows x 1 columns]

# %%
games
# Out:
#    season_id team_id_home team_abbreviation_home           team_name_home  \
# 0      21946   1610610035                    HUS          Toronto Huskies
# 1      21946   1610610034                    BOM        St. Louis Bombers
# 2      21946   1610610032                    PRO  Providence Steamrollers
# 3      21946   1610610025                    CHS            Chicago Stags
# 4      21946   1610610028                    DEF          Detroit Falcons
# ..       ...          ...                    ...                      ...
# 95     21946   1610612738                    BOS           Boston Celtics
# 96     21946   1610610034                    BOM        St. Louis Bombers
# 97     21946   1610610026                    CLR         Cleveland Rebels
# 98     21946   1610610025                    CHS            Chicago Stags
# 99     21946   1610610031                    PIT       Pittsburgh Ironmen
#
#        game_id            game_date matchup_home wl_home  min  fgm_home  ...  \
# ...

# %%
all_games = pd.read_sql_query("SELECT * FROM game", con)

# %%
all_games.sort_values(by='game_date', ascending=False)
# Out:
#       season_id team_id_home team_abbreviation_home           team_name_home  \
# 65695     42022   1610612743                    DEN           Denver Nuggets
# 65694     42022   1610612748                    MIA               Miami Heat
# 65693     42022   1610612748                    MIA               Miami Heat
# 65692     42022   1610612743                    DEN           Denver Nuggets
# 65691     42022   1610612743                    DEN           Denver Nuggets
# ...         ...          ...                    ...                      ...
# 3         21946   1610610025                    CHS            Chicago Stags
# 2         21946   1610610032                    PRO  Providence Steamrollers
# 1         21946   1610610034                    BOM        St. Louis Bombers
# 4         21946   1610610028                    DEF          Detroit Falcons
# 0         21946   1610610035                    HUS          Toronto Huskies
#
# ...

# %%
den_recent = all_games[(all_games['team_abbreviation_home'] == 'DEN') & (all_games['season_id'] == '42022')]

# %%
den_recent
# Out:
#       season_id team_id_home team_abbreviation_home  team_name_home  \
# 65619     42022   1610612743                    DEN  Denver Nuggets
# 65625     42022   1610612743                    DEN  Denver Nuggets
# 65644     42022   1610612743                    DEN  Denver Nuggets
# 65654     42022   1610612743                    DEN  Denver Nuggets
# 65658     42022   1610612743                    DEN  Denver Nuggets
# 65672     42022   1610612743                    DEN  Denver Nuggets
# 65680     42022   1610612743                    DEN  Denver Nuggets
# 65682     42022   1610612743                    DEN  Denver Nuggets
# 65691     42022   1610612743                    DEN  Denver Nuggets
# 65692     42022   1610612743                    DEN  Denver Nuggets
# 65695     42022   1610612743                    DEN  Denver Nuggets
#
#           game_id            game_date matchup_home wl_home  min  fgm_home  \
# ...

# %%
avg_away = den_recent['pts_away'].mean()
avg_away
# Out:
# 101.81818181818181

# %%
avg_home = den_recent['pts_home'].mean()
avg_home
# Out:
# 111.72727272727273
