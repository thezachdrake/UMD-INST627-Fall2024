# %%
# crime type is HARRASSMENT 2, I sorted the dataset by the description of the premises
import pandas as pd
df = pd.read_csv('data/data.csv')
har = df['OFNS_DESC'] == 'HARRASSMENT 2'
df[har].sort_values('PREM_TYP_DESC')
# Out:
#        CMPLNT_NUM  ADDR_PCT_CD    BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM  \
# 100832  283733002           67   BROOKLYN   03/08/2024     14:45:00
# 27430   280848656           34  MANHATTAN   01/19/2024     22:01:00
# 78363   282636965           44      BRONX   02/22/2024     12:00:00
# 27596   282487772           52      BRONX   01/19/2024     12:50:00
# 78120   282655477          114     QUEENS   02/22/2024     15:00:00
# ...           ...          ...        ...          ...          ...
# 131870  284769986          114     QUEENS   03/29/2024     23:15:00
# 91211   283104188          115     QUEENS   03/02/2024     17:20:00
# 70057   282993917           48      BRONX   02/16/2024     19:45:00
# 30545   280935422           10  MANHATTAN   01/22/2024     18:00:00
# 96676   283321299           72   BROOKLYN   03/06/2024     18:30:00
#
#        CMPLNT_TO_DT CMPLNT_TO_TM CRM_ATPT_CPTD_CD HADEVELOPT  HOUSING_PSA  \
# 100832   03/08/2024     14:55:00        COMPLETED     (null)          NaN
# ...
