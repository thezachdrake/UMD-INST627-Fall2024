# %%
import pandas as pd
crimes = pd.read_csv('data/crimes.csv')
arrests = pd.read_csv('data/arrests.csv')

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
crimes_arrests = crimes.merge(arrests, on='New Georeferenced Column', how='left', suffixes=('_cri', '_arr'))

crimes_arrests.head()
# Out:
#    Unnamed: 0 CMPLNT_NUM  ADDR_PCT_CD   BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM  \
# 0       51870  282411683           60  BROOKLYN   02/18/2024     12:10:00
# 1       51870  282411683           60  BROOKLYN   02/18/2024     12:10:00
# 2       51870  282411683           60  BROOKLYN   02/18/2024     12:10:00
# 3       51870  282411683           60  BROOKLYN   02/18/2024     12:10:00
# 4       51870  282411683           60  BROOKLYN   02/18/2024     12:10:00
#
#   CMPLNT_TO_DT CMPLNT_TO_TM CRM_ATPT_CPTD_CD HADEVELOPT  HOUSING_PSA  \
# 0   02/18/2024     12:18:00        COMPLETED     (null)          NaN
# 1   02/18/2024     12:18:00        COMPLETED     (null)          NaN
# 2   02/18/2024     12:18:00        COMPLETED     (null)          NaN
# 3   02/18/2024     12:18:00        COMPLETED     (null)          NaN
# 4   02/18/2024     12:18:00        COMPLETED     (null)          NaN
#
#    JURISDICTION_CODE_cri        JURIS_DESC  KY_CD_cri LAW_CAT_CD_cri  \
# 0                      0  N.Y. POLICE DEPT        235    MISDEMEANOR
# 1                      0  N.Y. POLICE DEPT        235    MISDEMEANOR
# 2                      0  N.Y. POLICE DEPT        235    MISDEMEANOR
# 3                      0  N.Y. POLICE DEPT        235    MISDEMEANOR
# 4                      0  N.Y. POLICE DEPT        235    MISDEMEANOR
#
#   LOC_OF_OCCUR_DESC    OFNS_DESC_cri PARKS_NM              PATROL_BORO  \
# 0            (null)  DANGEROUS DRUGS   (null)  PATROL BORO BKLYN SOUTH
# 1            (null)  DANGEROUS DRUGS   (null)  PATROL BORO BKLYN SOUTH
# 2            (null)  DANGEROUS DRUGS   (null)  PATROL BORO BKLYN SOUTH
# 3            (null)  DANGEROUS DRUGS   (null)  PATROL BORO BKLYN SOUTH
# 4            (null)  DANGEROUS DRUGS   (null)  PATROL BORO BKLYN SOUTH
#
#    PD_CD_cri                     PD_DESC_cri PREM_TYP_DESC      RPT_DT  \
# 0      511.0  CONTROLLED SUBSTANCE, POSSESSI        STREET  02/18/2024
# 1      511.0  CONTROLLED SUBSTANCE, POSSESSI        STREET  02/18/2024
# 2      511.0  CONTROLLED SUBSTANCE, POSSESSI        STREET  02/18/2024
# 3      511.0  CONTROLLED SUBSTANCE, POSSESSI        STREET  02/18/2024
# 4      511.0  CONTROLLED SUBSTANCE, POSSESSI        STREET  02/18/2024
#
#   STATION_NAME SUSP_AGE_GROUP SUSP_RACE SUSP_SEX  TRANSIT_DISTRICT  \
# 0       (null)          18-24     BLACK        M               NaN
# 1       (null)          18-24     BLACK        M               NaN
# 2       (null)          18-24     BLACK        M               NaN
# 3       (null)          18-24     BLACK        M               NaN
# 4       (null)          18-24     BLACK        M               NaN
#
#   VIC_AGE_GROUP VIC_RACE VIC_SEX  X_COORD_CD_cri  Y_COORD_CD_cri  \
# 0       UNKNOWN  UNKNOWN       E        990148.0        155255.0
# 1       UNKNOWN  UNKNOWN       E        990148.0        155255.0
# 2       UNKNOWN  UNKNOWN       E        990148.0        155255.0
# 3       UNKNOWN  UNKNOWN       E        990148.0        155255.0
# 4       UNKNOWN  UNKNOWN       E        990148.0        155255.0
#
#    Latitude_cri  Longitude_cri                                   Lat_Lon  \
# 0     40.592813     -73.978763  (40.592813307614215, -73.97876328945328)
# 1     40.592813     -73.978763  (40.592813307614215, -73.97876328945328)
# 2     40.592813     -73.978763  (40.592813307614215, -73.97876328945328)
# 3     40.592813     -73.978763  (40.592813307614215, -73.97876328945328)
# 4     40.592813     -73.978763  (40.592813307614215, -73.97876328945328)
#
#                         New Georeferenced Column   ARREST_KEY ARREST_DATE  \
# 0  POINT (-73.97876328945328 40.592813307614215)  279889691.0  01/03/2024
# 1  POINT (-73.97876328945328 40.592813307614215)  282413371.0  02/18/2024
# 2  POINT (-73.97876328945328 40.592813307614215)  282415571.0  02/18/2024
# 3  POINT (-73.97876328945328 40.592813307614215)  286271310.0  05/02/2024
# 4  POINT (-73.97876328945328 40.592813307614215)  288597884.0  06/16/2024
#
#    PD_CD_arr                     PD_DESC_arr  KY_CD_arr  \
# 0      724.0  FORGERY-ILLEGAL POSSESSION,VEH      126.0
# 1      511.0  CONTROLLED SUBSTANCE, POSSESSI      235.0
# 2      503.0  CONTROLLED SUBSTANCE,INTENT TO      117.0
# 3      515.0     CONTROLLED SUBSTANCE,SALE 3      117.0
# 4      397.0  ROBBERY,OPEN AREA UNCLASSIFIED      105.0
#
#              OFNS_DESC_arr    LAW_CODE LAW_CAT_CD_arr ARREST_BORO  \
# 0  MISCELLANEOUS PENAL LAW  PL 1706502              F           K
# 1          DANGEROUS DRUGS  PL 2200300              M           K
# 2          DANGEROUS DRUGS  PL 2201601              F           K
# 3          DANGEROUS DRUGS  PL 2203901              F           K
# 4                  ROBBERY  PL 1601502              F           K
#
#    ARREST_PRECINCT  JURISDICTION_CODE_arr AGE_GROUP PERP_SEX       PERP_RACE  \
# 0             60.0                    0.0     25-44        M           WHITE
# 1             60.0                    0.0     18-24        M           BLACK
# 2             60.0                    0.0     25-44        M           BLACK
# 3             61.0                    0.0     25-44        F           WHITE
# 4             61.0                    1.0     25-44        F  WHITE HISPANIC
#
#    X_COORD_CD_arr  Y_COORD_CD_arr  Latitude_arr  Longitude_arr
# 0        990148.0        155255.0     40.592813     -73.978763
# 1        990148.0        155255.0     40.592813     -73.978763
# 2        990148.0        155255.0     40.592813     -73.978763
# 3        990148.0        155255.0     40.592813     -73.978763
# 4        990148.0        155255.0     40.592813     -73.978763
