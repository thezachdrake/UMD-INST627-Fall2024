# %%
import pandas as pd
df = pd.read_csv("data/data.csv")
df = df[df.OFNS_DESC == "FELONY ASSAULT"]
df
# Out:
#        CMPLNT_NUM  ADDR_PCT_CD        BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM  \
# 19      279780199          120  STATEN ISLAND   01/01/2024     11:10:00
# 34      279768924            5      MANHATTAN   01/01/2024     03:20:00
# 66      279794549           76       BROOKLYN   01/01/2024     21:50:00
# 67      279768929           14      MANHATTAN   01/01/2024     01:51:00
# 72      279767625           68       BROOKLYN   01/01/2024     05:20:00
# ...           ...          ...            ...          ...          ...
# 134382  284565718          109         QUEENS   03/31/2024     02:45:00
# 134384  284586506          113         QUEENS   03/31/2024     15:10:00
# 134388  284574491          103         QUEENS   03/31/2024     10:45:00
# 134399  284567835          103         QUEENS   03/31/2024     04:35:00
# 134447  284565713          101         QUEENS   03/31/2024     03:57:00
#
#        CMPLNT_TO_DT CMPLNT_TO_TM CRM_ATPT_CPTD_CD HADEVELOPT  HOUSING_PSA  \
# ...

# %%
df.sort_values(by=["CMPLNT_NUM"])
# Out:
#        CMPLNT_NUM  ADDR_PCT_CD    BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM  \
# 1142    279764540           43      BRONX   01/01/2024     01:24:00
# 513     279764553           70   BROOKLYN   01/01/2024     00:25:00
# 456     279764558           79   BROOKLYN   01/01/2024     01:30:00
# 648     279764566          114     QUEENS   01/01/2024     01:00:00
# 269     279766999           14  MANHATTAN   01/01/2024     02:05:00
# ...           ...          ...        ...          ...          ...
# 99780   289057314           28  MANHATTAN   03/08/2024     11:28:00
# 9601    289116941           63   BROOKLYN   01/07/2024     22:54:00
# 9580    289116942           63   BROOKLYN   01/07/2024     22:54:00
# 63490   289199168           44      BRONX   02/12/2024     01:00:00
# 118161  289206716           70   BROOKLYN   03/20/2024     11:00:00
#
#        CMPLNT_TO_DT CMPLNT_TO_TM CRM_ATPT_CPTD_CD HADEVELOPT  HOUSING_PSA  \
# 1142     01/01/2024     02:29:00        COMPLETED     (null)          NaN
# ...
