# %%
import pandas as pd

df = pd.read_csv("data/data.csv")

#examining the columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134639 entries, 0 to 134638
# Data columns (total 36 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   CMPLNT_NUM                134639 non-null  object
#  1   ADDR_PCT_CD               134639 non-null  int64
#  2   BORO_NM                   134639 non-null  object
#  3   CMPLNT_FR_DT              134639 non-null  object
#  4   CMPLNT_FR_TM              134639 non-null  object
#  5   CMPLNT_TO_DT              127696 non-null  object
#  6   CMPLNT_TO_TM              134639 non-null  object
#  7   CRM_ATPT_CPTD_CD          134639 non-null  object
#  8   HADEVELOPT                134639 non-null  object
#  9   HOUSING_PSA               8559 non-null    float64
#  10  JURISDICTION_CODE         134639 non-null  int64
#  11  JURIS_DESC                134639 non-null  object
#  12  KY_CD                     134639 non-null  int64
# ...

# %%
#reviweing types of recorded offenses
print(df['OFNS_DESC'].unique())
# Out:
# ['CRIMINAL MISCHIEF & RELATED OF' 'GRAND LARCENY OF MOTOR VEHICLE'
#  'HARRASSMENT 2' 'FRAUDS' 'SEX CRIMES' 'PETIT LARCENY' 'BURGLARY'
#  'VEHICLE AND TRAFFIC LAWS' 'FELONY ASSAULT' 'DANGEROUS DRUGS'
#  'GRAND LARCENY' 'OFFENSES AGAINST PUBLIC ADMINI'
#  'MURDER & NON-NEGL. MANSLAUGHTER' 'ROBBERY'
#  'INTOXICATED & IMPAIRED DRIVING' 'MISCELLANEOUS PENAL LAW'
#  'OFF. AGNST PUB ORD SENSBLTY &' 'DANGEROUS WEAPONS' 'FORGERY' 'RAPE'
#  'NYS LAWS-UNCLASSIFIED FELONY' 'OTHER STATE LAWS (NON PENAL LA'
#  'CRIMINAL TRESPASS' 'ASSAULT 3 & RELATED OFFENSES' 'ADMINISTRATIVE CODE'
#  'UNAUTHORIZED USE OF A VEHICLE' 'ARSON' 'OFFENSES INVOLVING FRAUD'
#  'OFFENSES AGAINST THE PERSON' 'THEFT-FRAUD'
#  'AGRICULTURE & MRKTS LAW-UNCLASSIFIED' 'OTHER OFFENSES RELATED TO THEF'
#  'POSSESSION OF STOLEN PROPERTY' 'CANNABIS RELATED OFFENSES' 'GAMBLING'
#  'KIDNAPPING & RELATED OFFENSES' "BURGLAR'S TOOLS"
#  'ALCOHOLIC BEVERAGE CONTROL LAW' 'PETIT LARCENY OF MOTOR VEHICLE'
# ...

# %%
#subsetting the rows for disorderly conduct crimes & sorting based on location type ("PREM_TYP_DESC")

disorderly_conduct_crimes = df[df['OFNS_DESC'] == 'DISORDERLY CONDUCT']
disorderly_conduct_crimes = disorderly_conduct_crimes.sort_values("PREM_TYP_DESC")

print(disorderly_conduct_crimes['PREM_TYP_DESC'].unique())

#change pandas settings to display all columns
pd.set_option('display.max_columns', None)

disorderly_conduct_crimes
# Out:
# ['(null)' 'AIRPORT TERMINAL' 'BRIDGE' 'CLOTHING/BOUTIQUE'
#  'COMMERCIAL BUILDING' 'DEPARTMENT STORE' 'OTHER' 'PARK/PLAYGROUND'
#  'RESIDENCE - PUBLIC HOUSING' 'RESIDENCE-HOUSE' 'STREET'
#  'TRANSIT - NYC SUBWAY' 'TRANSIT FACILITY (OTHER)']
#        CMPLNT_NUM  ADDR_PCT_CD    BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM  \
# 53292   281711675          103     QUEENS   02/05/2024     20:55:00
# 10552   280146077            5  MANHATTAN   01/08/2024     10:25:00
# 10424   280146074            5  MANHATTAN   01/08/2024     10:25:00
# 10426   280146064            5  MANHATTAN   01/08/2024     10:00:00
# 10533   280154777            5  MANHATTAN   01/08/2024     01:30:00
# ...           ...          ...        ...          ...          ...
# 83584   282817879           79   BROOKLYN   02/26/2024     18:00:00
# 92834   283139969           40      BRONX   03/03/2024     23:41:00
# 104268  283538964           77   BROOKLYN   03/11/2024     12:15:00
# ...
