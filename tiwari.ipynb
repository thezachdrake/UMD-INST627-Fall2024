# %%
import pandas as pd
df = pd.read_csv("data/data.csv")
df = df[df["PD_DESC"] == "ASSAULT 3"]
df = df.sort_values("CMPLNT_FR_DT", ascending =False)
df
# Out:
#        CMPLNT_NUM  ADDR_PCT_CD        BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM  \
# 134638  284584388          103         QUEENS   03/31/2024     17:50:00
# 134362  284571760          114         QUEENS   03/31/2024     07:45:00
# 134109  284785768           71       BROOKLYN   03/31/2024     12:40:00
# 134110  284570403           30      MANHATTAN   03/31/2024     01:00:00
# 134127  284573350           26      MANHATTAN   03/31/2024     09:10:00
# ...           ...          ...            ...          ...          ...
# 1416    279792845           52          BRONX   01/01/2024     20:20:00
# 1413    279813114           75       BROOKLYN   01/01/2024     08:00:00
# 1411    279792849           73       BROOKLYN   01/01/2024     15:40:00
# 1410    279794541           69       BROOKLYN   01/01/2024     04:20:00
# 179     279769538          121  STATEN ISLAND   01/01/2024     05:00:00
#
#        CMPLNT_TO_DT CMPLNT_TO_TM CRM_ATPT_CPTD_CD HADEVELOPT  HOUSING_PSA  \
# ...
