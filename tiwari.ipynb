# %%
import pandas as pd
df = pd.read_csv("data/data.csv")
df = df[df["PD_DESC"] == "ASSAULT 3"]
df = sort_values("
df
# Out:
#        CMPLNT_NUM  ADDR_PCT_CD        BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM  \
# 179     279769538          121  STATEN ISLAND   01/01/2024     05:00:00
# 241     279794295          120  STATEN ISLAND   01/01/2024     21:30:00
# 296     279818436          120  STATEN ISLAND   01/01/2024     21:25:00
# 311     279786350            1      MANHATTAN   01/01/2024     16:00:00
# 319     279767627           72       BROOKLYN   01/01/2024     04:20:00
# ...           ...          ...            ...          ...          ...
# 134628  284562248          109         QUEENS   03/31/2024     00:52:00
# 134633  284561552          103         QUEENS   03/31/2024     00:10:00
# 134634  284588555          111         QUEENS   03/31/2024     18:40:00
# 134636  284640813          101         QUEENS   03/31/2024     20:20:00
# 134638  284584388          103         QUEENS   03/31/2024     17:50:00
#
#        CMPLNT_TO_DT CMPLNT_TO_TM CRM_ATPT_CPTD_CD HADEVELOPT  HOUSING_PSA  \
# ...
